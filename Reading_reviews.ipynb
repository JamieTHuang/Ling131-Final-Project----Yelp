# %%
import pandas as pd
import nltk

# %%
'''
import sys
# !{sys.executable} -m pip install --upgrade pip

'''

# %%
# This takes a few minutes
with open('review.json', 'r+') as f:
        data = f.readlines()
data = map(lambda x: x.rstrip(), data)       # removes trailing \n's
data_json_str = "[" + ','.join(data) + "]"  
review_df = pd.read_json(data_json_str)

# %%
review_df
# Out:
#                       review_id                 user_id  \
# 0        Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA
# 1        GJXCdrto3ASJOqKeVWPi6Q  yXQM5uF2jS6es16SJzNHfg
# 2        2TzJjDVDEuAW6MR5Vuc1ug  n6-Gk65cPZL6Uz8qRm3NYw
# 3        yi0R0Ugj_xUx_Nek0-_Qig  dacAIZ6fTM6mqwW5uxkskg
# 4        11a8sVPMUFtaC7_ABRkmtw  ssoyf2_x0EQMed6fgHeMyQ
# ...                         ...                     ...
# 6685895  0pCaq1hqAViS2N6ldlp_sQ  Xu_YazIajfsc7SRj1wJ6Mg
# 6685896  jPCXuSBbI_cPocgoNBhdkg  V6BjjQICDO4q7TT3ZhaPWw
# 6685897  zwzO3yPdGbdgGy3-XQ0SWg  PFiIECX8wuvi7P-1mCvIjA
# 6685898  o8Nc2BJhKJXM6tRHJDRuPA  wu5R5_N7q5iqCBh6NBX26Q
# 6685899  OKmOLFwtI-NjofTHAGzv1Q  Ej3mCvjcwVXCSPB_avIfjQ
#
#                     business_id  stars  useful  funny  cool  \
# 0        ujmEBvifdJM6h6RLv4wQIg      1       6      1     0
# 1        NZnhc2sEQy3RmzKTZnqtwQ      5       0      0     0
# 2        WTqjgwHlXbSFevF32_DJVw      5       3      0     0
# ...

# %%
with open('business.json', 'r+') as f:
        data = f.readlines()
data = map(lambda x: x.rstrip(), data)       # removes trailing \n's
data_json_str = "[" + ','.join(data) + "]"  
business_df = pd.read_json(data_json_str)

# %%
business_df
# Out:
#                    business_id                             name  \
# 0       1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1       QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2       gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3       xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4       HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
# ...                        ...                              ...
# 192604  nqb4kWcOwp8bFxzfvaDpZQ               Sanderson Plumbing
# 192605  vY2nLU5K20Pee-FdG0br1g                         Chapters
# 192606  MiEyUDKTjeci5TMfxVZPpg                   Phoenix Pavers
# 192607  zNMupayB2jEHVDOji8sxoQ            Beasley's Barber Shop
# 192608  c1f_VAX1KIK8-JoVhjbYOw                   Oriental Relax
#
#                                address             city state postal_code  \
# 0          2818 E Camino Acequia Drive          Phoenix    AZ       85016
# ...

# %%
business_df = business_df[(business_df['state']=='NV')| (business_df['state']=='AZ') | (business_df['state']=='AZ')]

# %%
# Out:
# 92998

# %%
merged_df = review_df.merge(business_df, on='business_id' ,how='right')

# %%
merged_df
# Out:
#                       review_id                 user_id  \
# 0        Q1sbwvVQXV2734tPgoKj4Q  hG7b0MtEbXx5QzbzE6C_VA
# 1        8Edv5pKe5lOBoN5UZTUI1w  RBXSJA372ilErzNwz0jXvQ
# 2        kEs5u0cGPtiSQCLW7b0l9g  x3brMMbJrAW9PwW5A6YL5w
# 3        Pm6qydbW58BB0zdWCPlBmg  Skzdl0sWhW88525a1vr59g
# 4        QWJVYwNxUY_Plu4Ipz33_A  3Y25VDfnQVcuc33T-U3Z6A
# ...                         ...                     ...
# 4403440  qByVVhoG6p_LhPAwnyZo0w  WhVnaHLcTVj3Vg8bw0wssA
# 4403441  2s3mrO7bgGjG01gmhqdDzA  _fGju43E8HBbNbvRwT0JfQ
# 4403442                     NaN                     NaN
# 4403443                     NaN                     NaN
# 4403444                     NaN                     NaN
#
#                     business_id  stars_x  useful  funny  cool  \
# 0        ujmEBvifdJM6h6RLv4wQIg      1.0     6.0    1.0   0.0
# 1        ujmEBvifdJM6h6RLv4wQIg      4.0     0.0    0.0   0.0
# 2        ujmEBvifdJM6h6RLv4wQIg      1.0     1.0    0.0   0.0
# ...
